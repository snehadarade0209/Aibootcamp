# %%
# !pip install wordcloud

# %%
# Import necessary libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Ensure necessary NLTK data is downloaded
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sneha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sneha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Provided text
text = """
Artificial Intelligence (AI) is a transformative technology that mimics human intelligence through advanced algorithms and data processing. It allows machines to learn, adapt, and perform tasks such as problem-solving and decision-making. AI is used in various fields like healthcare, finance, and entertainment, driving efficiencies and fostering innovation. Its potential to revolutionize the world is immense, offering exciting possibilities for the future.
"""
print(text)
# Out:
# Artificial Intelligence (AI) is a transformative technology that mimics human intelligence through advanced algorithms and data processing. It allows machines to learn, adapt, and perform tasks such as problem-solving and decision-making. AI is used in various fields like healthcare, finance, and entertainment, driving efficiencies and fostering innovation. Its potential to revolutionize the world is immense, offering exciting possibilities for the future.

# %%
# Tokenization of words
words = word_tokenize(text.lower())  # Convert to lowercase for uniformity
print(words)
# Out:
# ['artificial', 'intelligence', '(', 'ai', ')', 'is', 'a', 'transformative', 'technology', 'that', 'mimics', 'human', 'intelligence', 'through', 'advanced', 'algorithms', 'and', 'data', 'processing', '.', 'it', 'allows', 'machines', 'to', 'learn', ',', 'adapt', ',', 'and', 'perform', 'tasks', 'such', 'as', 'problem-solving', 'and', 'decision-making', '.', 'ai', 'is', 'used', 'in', 'various', 'fields', 'like', 'healthcare', ',', 'finance', ',', 'and', 'entertainment', ',', 'driving', 'efficiencies', 'and', 'fostering', 'innovation', '.', 'its', 'potential', 'to', 'revolutionize', 'the', 'world', 'is', 'immense', ',', 'offering', 'exciting', 'possibilities', 'for', 'the', 'future', '.']

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
# The general syntax for a list comprehension is: [expression for item in iterable if condition]
print(filtered_words)
# Out:
# ['artificial', 'intelligence', 'ai', 'transformative', 'technology', 'mimics', 'human', 'intelligence', 'advanced', 'algorithms', 'data', 'processing', 'allows', 'machines', 'learn', 'adapt', 'perform', 'tasks', 'ai', 'used', 'various', 'fields', 'like', 'healthcare', 'finance', 'entertainment', 'driving', 'efficiencies', 'fostering', 'innovation', 'potential', 'revolutionize', 'world', 'immense', 'offering', 'exciting', 'possibilities', 'future']

# %%
# Frequency distribution of words
word_freq = Counter(filtered_words)
print(word_freq)
# Out:
# Counter({'intelligence': 2, 'ai': 2, 'artificial': 1, 'transformative': 1, 'technology': 1, 'mimics': 1, 'human': 1, 'advanced': 1, 'algorithms': 1, 'data': 1, 'processing': 1, 'allows': 1, 'machines': 1, 'learn': 1, 'adapt': 1, 'perform': 1, 'tasks': 1, 'used': 1, 'various': 1, 'fields': 1, 'like': 1, 'healthcare': 1, 'finance': 1, 'entertainment': 1, 'driving': 1, 'efficiencies': 1, 'fostering': 1, 'innovation': 1, 'potential': 1, 'revolutionize': 1, 'world': 1, 'immense': 1, 'offering': 1, 'exciting': 1, 'possibilities': 1, 'future': 1})

# %%
# Create a WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# %%
# Plotting the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axes
plt.show()
